# %% [markdown]
# <a href="https://colab.research.google.com/github/vitroid/yamanashi-water/blob/main/air/nox2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
    # On Google Colab
    from google.colab import drive
    drive.mount('/content/drive')

    BASEDIR="drive/MyDrive/DataAnalysis/相模湖・津久井湖土地・水質/yamanashi-water/air/"
except:
    BASEDIR="./"

# %% [markdown]
# 大気以外の窒素寄与が年々直線的に減少すると仮定する場合。

# %%
import pandas as pd

flows = pd.read_csv(f"{BASEDIR}../flow/9bridges2000.csv") # 2000年4月以降の252ヵ月
flows
# Out:
#      Unnamed: 0  ('昭和橋', '流量')  ('昭和橋', '全窒素')  ('大月橋', '流量')  ('大月橋', '全窒素')  \
# 0             0         1.0200            1.60         2.0700             1.7
# 1             1         0.9700            1.30         5.5200             1.6
# 2             2         0.5700            1.50         2.3100             1.6
# 3             3         1.3400            1.40         5.3000             1.7
# 4             4         5.1800            0.29         4.8000             1.4
# ..          ...            ...             ...            ...             ...
# 247         247         4.4277            0.57         2.9422             1.0
# 248         248         4.4304            0.66         2.2754             1.1
# 249         249         0.9716            1.30         1.8195             1.2
# 250         250         1.8441            1.00         1.6346             1.3
# 251         251         2.0594            1.00         1.4570             1.2
#
#      ('桂川橋', '流量')  ('桂川橋', '全窒素')  ('富士見橋', '流量')  ('富士見橋', '全窒素')  \
# 0          32.3200             1.6          2.9300             1.20
# 1          39.1000             1.5          2.6200             1.20
# 2          48.7000             1.5          2.3800             1.20
# 3          41.0000             1.5          3.8500             1.30
# 4          43.9800             1.3          4.3100             1.10
# ..             ...             ...             ...              ...
# 247        35.3546             1.1          4.5551             1.00
# 248        32.6497             1.2          4.5471             1.00
# 249        23.0379             1.3          4.8280             0.98
# 250        22.1846             1.2          4.7207             0.97
# 251        23.6344             1.2          4.4706             0.88
#
#      ('鶴川橋', '流量')  ...  ('西方寺橋', '流量')  ('西方寺橋', '全窒素')  ('落合橋', '流量')  \
# 0           1.9800  ...          0.9400             1.30         0.1400
# 1           0.6300  ...          0.9900             1.50         0.2600
# 2           0.3500  ...          0.7400             1.20         0.1200
# 3           2.3200  ...          2.4800             1.00         0.5500
# 4           1.5800  ...          1.8400             0.95         0.3300
# ..             ...  ...             ...              ...            ...
# 247         1.9370  ...          2.4134             0.79         0.7972
# 248         0.8985  ...          1.2589             0.75         0.1979
# 249         0.4651  ...          1.0088             0.98         0.1561
# 250         0.4367  ...          0.9354             1.10         0.0587
# 251         0.3583  ...          0.8447             1.00         0.0463
#
#      ('落合橋', '全窒素')  ('流川', '流量')  ('流川', '全窒素')  ('道志川', '流量')  \
# 0              1.30        3.1500            2.2         7.5700
# 1              1.30        2.7500            2.0         3.9600
# 2              1.40        2.7900            1.8         1.7900
# 3              1.20        2.7300            1.8         5.4700
# 4              1.20        3.5300            1.5         5.1900
# ..              ...           ...            ...            ...
# 247            0.76        3.2027            1.3         5.7238
# 248            0.83        1.7326            1.2         2.8614
# 249            0.83        1.4969            1.4         2.0964
# 250            0.88        1.5867            1.3         1.9493
# 251            0.90        1.6452            1.4         2.2869
#
#      ('道志川', '全窒素')  ('秋山川', '流量')  ('秋山川', '全窒素')
# 0              0.88         2.1400            1.50
# 1              0.68         0.9300            1.00
# 2              0.63         0.3800            1.00
# 3              0.70         2.1700            1.20
# 4              0.62         1.3300            1.00
# ..              ...            ...             ...
# 247            0.46         1.5480            0.59
# 248            0.37         0.6905            0.58
# 249            0.40         0.4306            0.64
# 250            0.44         0.4629            0.70
# 251            0.53         0.4551            0.65
#
# [252 rows x 21 columns]

# %%
import pandas as pd
import numpy as np


# read_csvが読み損じるので、自分で読む。
def read_csv(filename, sep=",", encoding="utf8"):
    rows = []
    with open(filename, encoding=encoding) as f:
        for line in f.readlines():
            cols = line.split(sep)[:143]
            rows.append(cols)
    df = pd.DataFrame(rows[1:])
    df.columns = rows[0][:143]
    print(rows[0][:143])
    return df


cols = """月平均値(ppm)_４月
同左_５月.2
同左_６月.2
同左_７月.2
同左_８月.2
同左_９月.2
同左_10月.2
同左_11月.2
同左_12月.2
同左_１月.2
同左_２月.2
同左_３月.2
""".splitlines()

# 2008年のデータはコラム名をつけまちがっている!!!信じられん。

stations = [19202030, 19204010, 19206010]

nox = []
for year in range(2000, 2021):
    if year >= 2003:
        cols = "月平均値(ppm)_４月,月平均値(ppm)_５月,月平均値(ppm)_６月,月平均値(ppm)_７月,月平均値(ppm)_８月,月平均値(ppm)_９月,月平均値(ppm)_10月,月平均値(ppm)_11月,月平均値(ppm)_12月,月平均値(ppm)_１月,月平均値(ppm)_２月,月平均値(ppm)_３月".split(
            ","
        )
    filename = f"{BASEDIR}../TD20231218_155555_51/TD{year}0419.txt"
    cols_in_file = list(
        pd.read_csv(
            filename,
            sep=",",
            nrows=1,
            encoding="cp932",
        )
    )
    print(len(cols_in_file))
    df = pd.read_csv(
        filename,
        encoding="cp932",
        sep=",",
        usecols=cols_in_file,
    )
    df = df.loc[:, ~df.columns.duplicated()]
    print(year, df)
    for i, col in enumerate(cols):
        month = i + 4
        y = year
        if month > 12:
            y += 1
            month -= 12
        row = []
        for station in stations:
            rows = df[df["測定局コード"] == station]
            if len(rows) > 0:
                row.append(rows.iloc[0][col])
            else:
                row.append(np.NaN)
        print(row)
        nox.append([float(x) for x in row])

nox = pd.DataFrame(nox, columns=stations)

nox
# Out:
# 175
# 2000     測定年度  項目種類コード  項目コード_数字 項目コード_英数字  測定方法コード  都道府県コード 都道府県名        同左_ローマ字  \
# 0   2000        1         4       NOX        1       19   山梨県  Yamanashi-keｎ
# 1   2000        1         4       NOX        2       19   山梨県  Yamanashi-keｎ
# 2   2000        1         4       NOX        1       19   山梨県  Yamanashi-keｎ
# 3   2000        1         4       NOX        1       19   山梨県  Yamanashi-keｎ
# 4   2000        1         4       NOX        1       19   山梨県  Yamanashi-keｎ
# 5   2000        1         4       NOX        2       19   山梨県  Yamanashi-keｎ
# 6   2000        1         4       NOX        1       19   山梨県  Yamanashi-keｎ
# 7   2000        1         4       NOX        1       19   山梨県  Yamanashi-keｎ
# 8   2000        1         4       NOX        1       19   山梨県  Yamanashi-keｎ
# 9   2000        1         4       NOX        1       19   山梨県  Yamanashi-keｎ
# 10  2000        1         4       NOX        2       19   山梨県  Yamanashi-keｎ
#
#     市区町村コード  市区町村名  ... Unnamed: 165  Unnamed: 166 Unnamed: 167  登録_年  登録_月  \
# 0     19201    甲府市  ...          NaN           NaN          NaN  2003    11
# 1     19201    甲府市  ...          NaN           NaN          NaN  2003    11
# 2     19202  富士吉田市  ...          NaN           NaN          NaN  2003    11
# 3     19204    都留市  ...          NaN           NaN          NaN  2003    11
# 4     19205    山梨市  ...          NaN           NaN          NaN  2003    11
# 5     19206    大月市  ...          NaN           NaN          NaN  2003    11
# 6     19207    韮崎市  ...          NaN           NaN          NaN  2003    11
# 7     19321    石和町  ...          NaN           NaN          NaN  2003    11
# 8     19365    身延町  ...          NaN           NaN          NaN  2003    11
# 9     19390    櫛形町  ...          NaN           NaN          NaN  2003    11
# 10    19441   上野原町  ...          NaN           NaN          NaN  2003    11
#
#     登録_日  最終更新_年 最終更新_月  最終更新_日  ファイルversion
# 0     20    2003     11      20      VER.1.0
# 1     20    2003     11      20      VER.1.0
# 2     20    2003     11      20      VER.1.0
# 3     20    2003     11      20      VER.1.0
# 4     20    2003     11      20      VER.1.0
# 5     20    2003     11      20      VER.1.0
# 6     20    2003     11      20      VER.1.0
# 7     20    2003     11      20      VER.1.0
# 8     20    2003     11      20      VER.1.0
# 9     20    2003     11      20      VER.1.0
# 10    20    2003     11      20      VER.1.0
#
# [11 rows x 175 columns]
# [0.011, 0.024, 0.03]
# [0.009, 0.027, 0.024]
# [0.011, 0.029, 0.027]
# [0.01, 0.023, 0.023]
# [0.011, 0.023, 0.022]
# [0.017, 0.028, 0.033]
# [0.02, 0.038, 0.038]
# [0.025, 0.044, 0.052]
# [0.027, 0.036, 0.071]
# [0.023, 0.032, 0.062]
# [0.023, 0.032, 0.064]
# [0.015, 0.028, 0.044]
# 175
# 2001     測定年度  項目種類コード  項目コード_数字 項目コード_英数字  測定方法コード  都道府県コード 都道府県名        同左_ローマ字  \
# 0   2001        1         4       NOX        2       19   山梨県  Yamanashi-keｎ
# 1   2001        1         4       NOX        2       19   山梨県  Yamanashi-keｎ
# 2   2001        1         4       NOX        2       19   山梨県  Yamanashi-keｎ
# 3   2001        1         4       NOX        1       19   山梨県  Yamanashi-keｎ
# 4   2001        1         4       NOX        1       19   山梨県  Yamanashi-keｎ
# 5   2001        1         4       NOX        2       19   山梨県  Yamanashi-keｎ
# 6   2001        1         4       NOX        1       19   山梨県  Yamanashi-keｎ
# 7   2001        1         4       NOX        2       19   山梨県  Yamanashi-keｎ
# 8   2001        1         4       NOX        2       19   山梨県  Yamanashi-keｎ
# 9   2001        1         4       NOX        1       19   山梨県  Yamanashi-keｎ
# 10  2001        1         4       NOX        2       19   山梨県  Yamanashi-keｎ
#
#     市区町村コード  市区町村名  ... Unnamed: 165  Unnamed: 166 Unnamed: 167  登録_年  登録_月  \
# 0     19201    甲府市  ...          NaN           NaN          NaN  2003    11
# 1     19201    甲府市  ...          NaN           NaN          NaN  2003    11
# 2     19202  富士吉田市  ...          NaN           NaN          NaN  2003    11
# 3     19203    塩山市  ...          NaN           NaN          NaN  2003    11
# 4     19204    都留市  ...          NaN           NaN          NaN  2003    11
# 5     19206    大月市  ...          NaN           NaN          NaN  2003    11
# 6     19207    韮崎市  ...          NaN           NaN          NaN  2003    11
# 7     19321    石和町  ...          NaN           NaN          NaN  2003    11
# 8     19365    身延町  ...          NaN           NaN          NaN  2003    11
# 9     19390    櫛形町  ...          NaN           NaN          NaN  2003    11
# 10    19441   上野原町  ...          NaN           NaN          NaN  2003    11
#
#     登録_日  最終更新_年 最終更新_月  最終更新_日  ファイルversion
# 0     20    2003     11      20      VER.1.0
# 1     20    2003     11      20      VER.1.0
# 2     20    2003     11      20      VER.1.0
# 3     20    2003     11      20      VER.1.0
# 4     20    2003     11      20      VER.1.0
# 5     20    2003     11      20      VER.1.0
# 6     20    2003     11      20      VER.1.0
# 7     20    2003     11      20      VER.1.0
# 8     20    2003     11      20      VER.1.0
# 9     20    2003     11      20      VER.1.0
# 10    20    2003     11      20      VER.1.0
#
# [11 rows x 175 columns]
# [0.012, 0.02, 0.034]
# [0.01, 0.019, 0.03]
# [0.012, 0.023, 0.027]
# [0.01, 0.016, 0.027]
# [0.012, 0.025, 0.045]
# [0.012, 0.023, 0.034]
# [0.015, 0.029, 0.044]
# [0.019, 0.03, 0.067]
# [0.02, 0.033, 0.072]
# [0.019, 0.025, 0.06]
# [0.02, 0.025, 0.058]
# [0.012, 0.027, 0.044]
# 175
# 2002     測定年度  項目種類コード  項目コード_数字 項目コード_英数字  測定方法コード  都道府県コード 都道府県名        同左_ローマ字  \
# 0   2002        1         4       NOX        2       19   山梨県  Yamanashi-keｎ
# 1   2002        1         4       NOX        2       19   山梨県  Yamanashi-keｎ
# 2   2002        1         4       NOX        2       19   山梨県  Yamanashi-keｎ
# 3   2002        1         4       NOX        1       19   山梨県  Yamanashi-keｎ
# 4   2002        1         4       NOX        1       19   山梨県  Yamanashi-keｎ
# 5   2002        1         4       NOX        2       19   山梨県  Yamanashi-keｎ
# 6   2002        1         4       NOX        1       19   山梨県  Yamanashi-keｎ
# 7   2002        1         4       NOX        2       19   山梨県  Yamanashi-keｎ
# 8   2002        1         4       NOX        2       19   山梨県  Yamanashi-keｎ
# 9   2002        1         4       NOX        2       19   山梨県  Yamanashi-keｎ
# 10  2002        1         4       NOX        1       19   山梨県  Yamanashi-keｎ
# 11  2002        1         4       NOX        2       19   山梨県  Yamanashi-keｎ
#
#     市区町村コード  市区町村名  ... Unnamed: 165  Unnamed: 166 Unnamed: 167  登録_年  登録_月  \
# 0     19201    甲府市  ...          NaN           NaN          NaN  2003    11
# 1     19201    甲府市  ...          NaN           NaN          NaN  2003    11
# 2     19202  富士吉田市  ...          NaN           NaN          NaN  2003    11
# 3     19203    塩山市  ...          NaN           NaN          NaN  2003    11
# 4     19204    都留市  ...          NaN           NaN          NaN  2003    11
# 5     19206    大月市  ...          NaN           NaN          NaN  2003    11
# 6     19207    韮崎市  ...          NaN           NaN          NaN  2003    11
# 7     19321    石和町  ...          NaN           NaN          NaN  2003    11
# 8     19365    身延町  ...          NaN           NaN          NaN  2003    11
# 9     19366    南部町  ...          NaN           NaN          NaN  2003    11
# 10    19390    櫛形町  ...          NaN           NaN          NaN  2003    11
# 11    19441   上野原町  ...          NaN           NaN          NaN  2003    11
#
#     登録_日  最終更新_年 最終更新_月  最終更新_日  ファイルversion
# 0     20    2003     11      20      VER.1.0
# 1     20    2003     11      20      VER.1.0
# 2     20    2003     11      20      VER.1.0
# 3     20    2003     11      20      VER.1.0
# 4     20    2003     11      20      VER.1.0
# 5     20    2003     11      20      VER.1.0
# 6     20    2003     11      20      VER.1.0
# 7     20    2003     11      20      VER.1.0
# 8     20    2003     11      20      VER.1.0
# 9     20    2003     11      20      VER.1.0
# 10    20    2003     11      20      VER.1.0
# 11    20    2003     11      20      VER.1.0
#
# [12 rows x 175 columns]
# [0.012, 0.023, 0.03]
# [0.012, 0.024, 0.028]
# [0.012, 0.026, 0.025]
# [0.009, 0.021, 0.023]
# [0.01, 0.019, 0.023]
# [0.013, 0.023, 0.027]
# [0.015, 0.026, 0.039]
# [0.018, 0.033, 0.059]
# [0.023, 0.037, 0.074]
# [0.019, 0.028, 0.06]
# [0.021, 0.039, 0.053]
# [0.015, 0.034, 0.044]
# 143
# 2003     測定年度  項目種類コード  項目コード_数字 項目コード_英数字  測定方法コード  都道府県コード 都道府県名     都道府県名_ローマ字  \
# 0   2003        1         4       NOX        2       19   山梨県  Yamanashi-keｎ
# 1   2003        1         4       NOX        2       19   山梨県  Yamanashi-keｎ
# 2   2003        1         4       NOX        2       19   山梨県  Yamanashi-keｎ
# 3   2003        1         4       NOX        1       19   山梨県  Yamanashi-keｎ
# 4   2003        1         4       NOX        1       19   山梨県  Yamanashi-keｎ
# 5   2003        1         4       NOX        2       19   山梨県  Yamanashi-keｎ
# 6   2003        1         4       NOX        2       19   山梨県  Yamanashi-keｎ
# 7   2003        1         4       NOX        1       19   山梨県  Yamanashi-keｎ
# 8   2003        1         4       NOX        2       19   山梨県  Yamanashi-keｎ
# 9   2003        1         4       NOX        2       19   山梨県  Yamanashi-keｎ
# 10  2003        1         4       NOX        2       19   山梨県  Yamanashi-keｎ
#
#     市区町村コード   市区町村名  ... 月間集計項目9_６月  月間集計項目9_７月 月間集計項目9_８月 月間集計項目9_９月  \
# 0     19201     甲府市  ...        NaN         NaN        NaN        NaN
# 1     19201     甲府市  ...        NaN         NaN        NaN        NaN
# 2     19202   富士吉田市  ...        NaN         NaN        NaN        NaN
# 3     19203     塩山市  ...        NaN         NaN        NaN        NaN
# 4     19204     都留市  ...        NaN         NaN        NaN        NaN
# 5     19206     大月市  ...        NaN         NaN        NaN        NaN
# 6     19207     韮崎市  ...        NaN         NaN        NaN        NaN
# 7     19208  南アルプス市  ...        NaN         NaN        NaN        NaN
# 8     19321     石和町  ...        NaN         NaN        NaN        NaN
# 9     19366     南部町  ...        NaN         NaN        NaN        NaN
# 10    19441    上野原町  ...        NaN         NaN        NaN        NaN
#
#     月間集計項目9_10月  月間集計項目9_11月  月間集計項目9_12月 月間集計項目9_１月  月間集計項目9_２月  月間集計項目9_３月
# 0           NaN          NaN          NaN        NaN         NaN         NaN
# 1           NaN          NaN          NaN        NaN         NaN         NaN
# 2           NaN          NaN          NaN        NaN         NaN         NaN
# 3           NaN          NaN          NaN        NaN         NaN         NaN
# 4           NaN          NaN          NaN        NaN         NaN         NaN
# 5           NaN          NaN          NaN        NaN         NaN         NaN
# 6           NaN          NaN          NaN        NaN         NaN         NaN
# 7           NaN          NaN          NaN        NaN         NaN         NaN
# 8           NaN          NaN          NaN        NaN         NaN         NaN
# 9           NaN          NaN          NaN        NaN         NaN         NaN
# 10          NaN          NaN          NaN        NaN         NaN         NaN
#
# [11 rows x 143 columns]
# [0.012, 0.021, 0.035]
# [0.012, 0.02, 0.026]
# [0.011, 0.021, 0.024]
# [0.013, 0.028, 0.038]
# [0.011, 0.023, 0.033]
# [0.012, 0.026, 0.033]
# [0.017, 0.029, 0.038]
# [0.02, 0.046, 0.046]
# [0.02, 0.037, 0.062]
# [0.02, 0.03, 0.057]
# [0.016, 0.031, 0.061]
# [0.016, 0.029, 0.043]
# 143
# 2004     測定年度  項目種類コード  項目コード_数字 項目コード_英数字  測定方法コード  都道府県コード 都道府県名     都道府県名_ローマ字  \
# 0   2004        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 1   2004        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 2   2004        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 3   2004        1         4       NOX        1       19   山梨県  Yamanashi-ken
# 4   2004        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 5   2004        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 6   2004        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 7   2004        1         4       NOX        1       19   山梨県  Yamanashi-ken
# 8   2004        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 9   2004        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 10  2004        1         4       NOX        2       19   山梨県  Yamanashi-ken
#
#     市区町村コード   市区町村名  ... 月間集計項目9_６月  月間集計項目9_７月 月間集計項目9_８月 月間集計項目9_９月  \
# 0     19201     甲府市  ...        NaN         NaN        NaN        NaN
# 1     19201     甲府市  ...        NaN         NaN        NaN        NaN
# 2     19202   富士吉田市  ...        NaN         NaN        NaN        NaN
# 3     19203     塩山市  ...        NaN         NaN        NaN        NaN
# 4     19204     都留市  ...        NaN         NaN        NaN        NaN
# 5     19206     大月市  ...        NaN         NaN        NaN        NaN
# 6     19207     韮崎市  ...        NaN         NaN        NaN        NaN
# 7     19208  南アルプス市  ...        NaN         NaN        NaN        NaN
# 8     19211     笛吹市  ...        NaN         NaN        NaN        NaN
# 9     19212    上野原市  ...        NaN         NaN        NaN        NaN
# 10    19366     南部町  ...        NaN         NaN        NaN        NaN
#
#     月間集計項目9_10月  月間集計項目9_11月  月間集計項目9_12月 月間集計項目9_１月  月間集計項目9_２月  月間集計項目9_３月
# 0           NaN          NaN          NaN        NaN         NaN         NaN
# 1           NaN          NaN          NaN        NaN         NaN         NaN
# 2           NaN          NaN          NaN        NaN         NaN         NaN
# 3           NaN          NaN          NaN        NaN         NaN         NaN
# 4           NaN          NaN          NaN        NaN         NaN         NaN
# 5           NaN          NaN          NaN        NaN         NaN         NaN
# 6           NaN          NaN          NaN        NaN         NaN         NaN
# 7           NaN          NaN          NaN        NaN         NaN         NaN
# 8           NaN          NaN          NaN        NaN         NaN         NaN
# 9           NaN          NaN          NaN        NaN         NaN         NaN
# 10          NaN          NaN          NaN        NaN         NaN         NaN
#
# [11 rows x 143 columns]
# [0.011, 0.019, 0.032]
# [0.012, 0.022, 0.024]
# [0.011, 0.02, 0.026]
# [0.01, 0.018, 0.024]
# [0.01, 0.019, 0.02]
# [0.011, 0.021, 0.026]
# [0.015, 0.03, 0.035]
# [0.019, 0.029, 0.057]
# [0.022, 0.031, 0.067]
# [0.018, 0.026, 0.06]
# [0.019, 0.029, 0.048]
# [0.014, 0.025, 0.049]
# 143
# 2005     測定年度  項目種類コード  項目コード_数字 項目コード_英数字  測定方法コード  都道府県コード 都道府県名     都道府県名_ローマ字  \
# 0   2005        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 1   2005        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 2   2005        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 3   2005        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 4   2005        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 5   2005        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 6   2005        1         4       NOX        1       19   山梨県  Yamanashi-ken
# 7   2005        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 8   2005        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 9   2005        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 10  2005        1         4       NOX        2       19   山梨県  Yamanashi-ken
#
#     市区町村コード   市区町村名  ... 月間集計項目9_６月  月間集計項目9_７月 月間集計項目9_８月 月間集計項目9_９月  \
# 0     19201     甲府市  ...        NaN         NaN        NaN        NaN
# 1     19201     甲府市  ...        NaN         NaN        NaN        NaN
# 2     19202   富士吉田市  ...        NaN         NaN        NaN        NaN
# 3     19204     都留市  ...        NaN         NaN        NaN        NaN
# 4     19206     大月市  ...        NaN         NaN        NaN        NaN
# 5     19207     韮崎市  ...        NaN         NaN        NaN        NaN
# 6     19208  南アルプス市  ...        NaN         NaN        NaN        NaN
# 7     19211     笛吹市  ...        NaN         NaN        NaN        NaN
# 8     19212    上野原市  ...        NaN         NaN        NaN        NaN
# 9     19213     甲州市  ...        NaN         NaN        NaN        NaN
# 10    19366     南部町  ...        NaN         NaN        NaN        NaN
#
#     月間集計項目9_10月  月間集計項目9_11月  月間集計項目9_12月 月間集計項目9_１月  月間集計項目9_２月  月間集計項目9_３月
# 0           NaN          NaN          NaN        NaN         NaN         NaN
# 1           NaN          NaN          NaN        NaN         NaN         NaN
# 2           NaN          NaN          NaN        NaN         NaN         NaN
# 3           NaN          NaN          NaN        NaN         NaN         NaN
# 4           NaN          NaN          NaN        NaN         NaN         NaN
# 5           NaN          NaN          NaN        NaN         NaN         NaN
# 6           NaN          NaN          NaN        NaN         NaN         NaN
# 7           NaN          NaN          NaN        NaN         NaN         NaN
# 8           NaN          NaN          NaN        NaN         NaN         NaN
# 9           NaN          NaN          NaN        NaN         NaN         NaN
# 10          NaN          NaN          NaN        NaN         NaN         NaN
#
# [11 rows x 143 columns]
# [0.011, 0.021, 0.032]
# [0.011, 0.019, 0.023]
# [0.01, 0.021, 0.024]
# [0.011, 0.024, 0.024]
# [0.008, 0.019, 0.021]
# [0.011, 0.022, 0.025]
# [0.012, 0.026, 0.032]
# [0.016, 0.025, 0.071]
# [0.016, 0.025, 0.071]
# [0.017, 0.03, 0.06]
# [0.019, 0.033, 0.055]
# [0.011, 0.024, 0.034]
# 143
# 2006     測定年度  項目種類コード  項目コード_数字 項目コード_英数字  測定方法コード  都道府県コード 都道府県名     都道府県名_ローマ字  \
# 0   2006        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 1   2006        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 2   2006        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 3   2006        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 4   2006        1         4       NOX        1       19   山梨県  Yamanashi-ken
# 5   2006        1         4       NOX        1       19   山梨県  Yamanashi-ken
# 6   2006        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 7   2006        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 8   2006        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 9   2006        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 10  2006        1         4       NOX        2       19   山梨県  Yamanashi-ken
#
#     市区町村コード   市区町村名  ... 月間集計項目9_６月  月間集計項目9_７月 月間集計項目9_８月 月間集計項目9_９月  \
# 0     19201     甲府市  ...        NaN         NaN        NaN        NaN
# 1     19201     甲府市  ...        NaN         NaN        NaN        NaN
# 2     19202   富士吉田市  ...        NaN         NaN        NaN        NaN
# 3     19204     都留市  ...        NaN         NaN        NaN        NaN
# 4     19213     甲州市  ...        NaN         NaN        NaN        NaN
# 5     19206     大月市  ...        NaN         NaN        NaN        NaN
# 6     19207     韮崎市  ...        NaN         NaN        NaN        NaN
# 7     19211     笛吹市  ...        NaN         NaN        NaN        NaN
# 8     19366     南部町  ...        NaN         NaN        NaN        NaN
# 9     19208  南アルプス市  ...        NaN         NaN        NaN        NaN
# 10    19212    上野原市  ...        NaN         NaN        NaN        NaN
#
#     月間集計項目9_10月  月間集計項目9_11月  月間集計項目9_12月 月間集計項目9_１月  月間集計項目9_２月  月間集計項目9_３月
# 0           NaN          NaN          NaN        NaN         NaN         NaN
# 1           NaN          NaN          NaN        NaN         NaN         NaN
# 2           NaN          NaN          NaN        NaN         NaN         NaN
# 3           NaN          NaN          NaN        NaN         NaN         NaN
# 4           NaN          NaN          NaN        NaN         NaN         NaN
# 5           NaN          NaN          NaN        NaN         NaN         NaN
# 6           NaN          NaN          NaN        NaN         NaN         NaN
# 7           NaN          NaN          NaN        NaN         NaN         NaN
# 8           NaN          NaN          NaN        NaN         NaN         NaN
# 9           NaN          NaN          NaN        NaN         NaN         NaN
# 10          NaN          NaN          NaN        NaN         NaN         NaN
#
# [11 rows x 143 columns]
# [0.011, 0.023, 0.033]
# [0.01, 0.018, 0.031]
# [0.01, 0.022, 0.029]
# [0.011, 0.022, 0.021]
# [0.01, 0.018, 0.024]
# [0.01, 0.02, 0.024]
# [0.012, 0.021, 0.034]
# [0.017, 0.026, 0.043]
# [0.02, 0.03, 0.054]
# [0.019, 0.024, 0.048]
# [0.014, 0.024, 0.046]
# [0.011, 0.02, 0.033]
# 143
# 2007     測定年度  項目種類コード  項目コード_数字 項目コード_英数字  測定方法コード  都道府県コード 都道府県名     都道府県名_ローマ字  \
# 0   2007        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 1   2007        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 2   2007        1         4       NOX        1       19   山梨県  Yamanashi-ken
# 3   2007        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 4   2007        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 5   2007        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 6   2007        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 7   2007        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 8   2007        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 9   2007        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 10  2007        1         4       NOX        2       19   山梨県  Yamanashi-ken
#
#     市区町村コード   市区町村名  ... 月間集計項目9_６月  月間集計項目9_７月 月間集計項目9_８月 月間集計項目9_９月  \
# 0     19201     甲府市  ...        NaN         NaN        NaN        NaN
# 1     19201     甲府市  ...        NaN         NaN        NaN        NaN
# 2     19213     甲州市  ...        NaN         NaN        NaN        NaN
# 3     19206     大月市  ...        NaN         NaN        NaN        NaN
# 4     19366     南部町  ...        NaN         NaN        NaN        NaN
# 5     19208  南アルプス市  ...        NaN         NaN        NaN        NaN
# 6     19202   富士吉田市  ...        NaN         NaN        NaN        NaN
# 7     19204     都留市  ...        NaN         NaN        NaN        NaN
# 8     19207     韮崎市  ...        NaN         NaN        NaN        NaN
# 9     19211     笛吹市  ...        NaN         NaN        NaN        NaN
# 10    19212    上野原市  ...        NaN         NaN        NaN        NaN
#
#     月間集計項目9_10月  月間集計項目9_11月  月間集計項目9_12月 月間集計項目9_１月  月間集計項目9_２月  月間集計項目9_３月
# 0           NaN          NaN          NaN        NaN         NaN         NaN
# 1           NaN          NaN          NaN        NaN         NaN         NaN
# 2           NaN          NaN          NaN        NaN         NaN         NaN
# 3           NaN          NaN          NaN        NaN         NaN         NaN
# 4           NaN          NaN          NaN        NaN         NaN         NaN
# 5           NaN          NaN          NaN        NaN         NaN         NaN
# 6           NaN          NaN          NaN        NaN         NaN         NaN
# 7           NaN          NaN          NaN        NaN         NaN         NaN
# 8           NaN          NaN          NaN        NaN         NaN         NaN
# 9           NaN          NaN          NaN        NaN         NaN         NaN
# 10          NaN          NaN          NaN        NaN         NaN         NaN
#
# [11 rows x 143 columns]
# [0.011, 0.019, 0.008]
# [0.008, 0.016, 0.023]
# [0.008, 0.016, 0.021]
# [0.011, 0.023, 0.023]
# [0.008, 0.017, 0.022]
# [0.009, 0.02, 0.022]
# [0.013, 0.022, 0.032]
# [0.016, 0.028, 0.044]
# [0.019, 0.029, 0.075]
# [0.017, 0.025, 0.051]
# [0.014, 0.021, 0.048]
# [0.012, 0.022, 0.034]
# 143
# 2008     測定年度  項目種類コード  項目コード_数字 項目コード_英数字  測定方法コード  都道府県コード 都道府県名     都道府県名_ローマ字  \
# 0   2008        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 1   2008        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 2   2008        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 3   2008        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 4   2008        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 5   2008        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 6   2008        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 7   2008        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 8   2008        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 9   2008        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 10  2008        1         4       NOX        2       19   山梨県  Yamanashi-ken
#
#     市区町村コード   市区町村名  ... 月間集計項目9_６月  月間集計項目9_７月 月間集計項目9_８月 月間集計項目9_９月  \
# 0     19201     甲府市  ...        NaN         NaN        NaN        NaN
# 1     19201     甲府市  ...        NaN         NaN        NaN        NaN
# 2     19202   富士吉田市  ...        NaN         NaN        NaN        NaN
# 3     19204     都留市  ...        NaN         NaN        NaN        NaN
# 4     19206     大月市  ...        NaN         NaN        NaN        NaN
# 5     19207     韮崎市  ...        NaN         NaN        NaN        NaN
# 6     19208  南アルプス市  ...        NaN         NaN        NaN        NaN
# 7     19211     笛吹市  ...        NaN         NaN        NaN        NaN
# 8     19212    上野原市  ...        NaN         NaN        NaN        NaN
# 9     19213     甲州市  ...        NaN         NaN        NaN        NaN
# 10    19366     南部町  ...        NaN         NaN        NaN        NaN
#
#     月間集計項目9_10月  月間集計項目9_11月  月間集計項目9_12月 月間集計項目9_１月  月間集計項目9_２月  月間集計項目9_３月
# 0           NaN          NaN          NaN        NaN         NaN         NaN
# 1           NaN          NaN          NaN        NaN         NaN         NaN
# 2           NaN          NaN          NaN        NaN         NaN         NaN
# 3           NaN          NaN          NaN        NaN         NaN         NaN
# 4           NaN          NaN          NaN        NaN         NaN         NaN
# 5           NaN          NaN          NaN        NaN         NaN         NaN
# 6           NaN          NaN          NaN        NaN         NaN         NaN
# 7           NaN          NaN          NaN        NaN         NaN         NaN
# 8           NaN          NaN          NaN        NaN         NaN         NaN
# 9           NaN          NaN          NaN        NaN         NaN         NaN
# 10          NaN          NaN          NaN        NaN         NaN         NaN
#
# [11 rows x 143 columns]
# [0.01, 0.019, 0.028]
# [0.008, 0.017, 0.022]
# [0.009, 0.017, 0.02]
# [0.008, 0.016, 0.02]
# [0.009, 0.016, 0.019]
# [0.009, 0.016, 0.022]
# [0.011, 0.019, 0.034]
# [0.014, 0.022, 0.044]
# [0.014, 0.022, 0.057]
# [0.015, 0.021, 0.049]
# [0.014, 0.024, 0.041]
# [0.01, 0.018, 0.028]
# 143
# 2009     測定年度  項目種類コード  項目コード_数字 項目コード_英数字  測定方法コード  都道府県コード 都道府県名     都道府県名_ローマ字  \
# 0   2009        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 1   2009        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 2   2009        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 3   2009        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 4   2009        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 5   2009        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 6   2009        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 7   2009        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 8   2009        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 9   2009        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 10  2009        1         4       NOX        2       19   山梨県  Yamanashi-ken
#
#     市区町村コード   市区町村名  ... 月間集計項目9_６月  月間集計項目9_７月 月間集計項目9_８月 月間集計項目9_９月  \
# 0     19201     甲府市  ...        NaN         NaN        NaN        NaN
# 1     19201     甲府市  ...        NaN         NaN        NaN        NaN
# 2     19202   富士吉田市  ...        NaN         NaN        NaN        NaN
# 3     19204     都留市  ...        NaN         NaN        NaN        NaN
# 4     19206     大月市  ...        NaN         NaN        NaN        NaN
# 5     19207     韮崎市  ...        NaN         NaN        NaN        NaN
# 6     19208  南アルプス市  ...        NaN         NaN        NaN        NaN
# 7     19211     笛吹市  ...        NaN         NaN        NaN        NaN
# 8     19212    上野原市  ...        NaN         NaN        NaN        NaN
# 9     19213     甲州市  ...        NaN         NaN        NaN        NaN
# 10    19366     南部町  ...        NaN         NaN        NaN        NaN
#
#     月間集計項目9_10月  月間集計項目9_11月  月間集計項目9_12月 月間集計項目9_１月  月間集計項目9_２月  月間集計項目9_３月
# 0           NaN          NaN          NaN        NaN         NaN         NaN
# 1           NaN          NaN          NaN        NaN         NaN         NaN
# 2           NaN          NaN          NaN        NaN         NaN         NaN
# 3           NaN          NaN          NaN        NaN         NaN         NaN
# 4           NaN          NaN          NaN        NaN         NaN         NaN
# 5           NaN          NaN          NaN        NaN         NaN         NaN
# 6           NaN          NaN          NaN        NaN         NaN         NaN
# 7           NaN          NaN          NaN        NaN         NaN         NaN
# 8           NaN          NaN          NaN        NaN         NaN         NaN
# 9           NaN          NaN          NaN        NaN         NaN         NaN
# 10          NaN          NaN          NaN        NaN         NaN         NaN
#
# [11 rows x 143 columns]
# [0.008, 0.015, 0.027]
# [0.007, 0.013, 0.023]
# [0.007, 0.015, 0.019]
# [0.007, 0.016, 0.021]
# [0.008, 0.015, 0.017]
# [0.009, 0.015, 0.019]
# [0.01, 0.016, 0.032]
# [0.013, 0.017, 0.04]
# [0.015, 0.018, 0.058]
# [0.013, 0.016, 0.052]
# [0.015, 0.014, 0.044]
# [0.011, 0.02, 0.028]
# 143
# 2010     測定年度  項目種類コード  項目コード_数字 項目コード_英数字  測定方法コード  都道府県コード 都道府県名     都道府県名_ローマ字  \
# 0   2010        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 1   2010        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 2   2010        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 3   2010        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 4   2010        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 5   2010        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 6   2010        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 7   2010        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 8   2010        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 9   2010        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 10  2010        1         4       NOX        2       19   山梨県  Yamanashi-ken
#
#     市区町村コード   市区町村名  ... 月間集計項目9_６月  月間集計項目9_７月 月間集計項目9_８月 月間集計項目9_９月  \
# 0     19201     甲府市  ...        NaN         NaN        NaN        NaN
# 1     19201     甲府市  ...        NaN         NaN        NaN        NaN
# 2     19202   富士吉田市  ...        NaN         NaN        NaN        NaN
# 3     19204     都留市  ...        NaN         NaN        NaN        NaN
# 4     19206     大月市  ...        NaN         NaN        NaN        NaN
# 5     19207     韮崎市  ...        NaN         NaN        NaN        NaN
# 6     19208  南アルプス市  ...        NaN         NaN        NaN        NaN
# 7     19211     笛吹市  ...        NaN         NaN        NaN        NaN
# 8     19212    上野原市  ...        NaN         NaN        NaN        NaN
# 9     19213     甲州市  ...        NaN         NaN        NaN        NaN
# 10    19366     南部町  ...        NaN         NaN        NaN        NaN
#
#     月間集計項目9_10月  月間集計項目9_11月  月間集計項目9_12月 月間集計項目9_１月  月間集計項目9_２月  月間集計項目9_３月
# 0           NaN          NaN          NaN        NaN         NaN         NaN
# 1           NaN          NaN          NaN        NaN         NaN         NaN
# 2           NaN          NaN          NaN        NaN         NaN         NaN
# 3           NaN          NaN          NaN        NaN         NaN         NaN
# 4           NaN          NaN          NaN        NaN         NaN         NaN
# 5           NaN          NaN          NaN        NaN         NaN         NaN
# 6           NaN          NaN          NaN        NaN         NaN         NaN
# 7           NaN          NaN          NaN        NaN         NaN         NaN
# 8           NaN          NaN          NaN        NaN         NaN         NaN
# 9           NaN          NaN          NaN        NaN         NaN         NaN
# 10          NaN          NaN          NaN        NaN         NaN         NaN
#
# [11 rows x 143 columns]
# [0.009, 0.016, 0.024]
# [0.007, 0.013, 0.02]
# [0.007, 0.013, 0.02]
# [0.006, 0.013, 0.018]
# [0.005, 0.011, 0.018]
# [0.006, 0.014, 0.021]
# [0.008, 0.017, 0.023]
# [0.009, 0.019, 0.047]
# [0.01, 0.02, 0.055]
# [0.009, 0.017, 0.051]
# [0.011, 0.022, 0.052]
# [0.009, 0.015, 0.032]
# 143
# 2011     測定年度  項目種類コード  項目コード_数字 項目コード_英数字  測定方法コード  都道府県コード 都道府県名     都道府県名_ローマ字  \
# 0   2011        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 1   2011        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 2   2011        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 3   2011        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 4   2011        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 5   2011        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 6   2011        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 7   2011        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 8   2011        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 9   2011        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 10  2011        1         4       NOX        2       19   山梨県  Yamanashi-ken
#
#     市区町村コード   市区町村名  ... 月間集計項目9_６月  月間集計項目9_７月 月間集計項目9_８月 月間集計項目9_９月  \
# 0     19201     甲府市  ...        NaN         NaN        NaN        NaN
# 1     19201     甲府市  ...        NaN         NaN        NaN        NaN
# 2     19202   富士吉田市  ...        NaN         NaN        NaN        NaN
# 3     19204     都留市  ...        NaN         NaN        NaN        NaN
# 4     19213     甲州市  ...        NaN         NaN        NaN        NaN
# 5     19206     大月市  ...        NaN         NaN        NaN        NaN
# 6     19207     韮崎市  ...        NaN         NaN        NaN        NaN
# 7     19211     笛吹市  ...        NaN         NaN        NaN        NaN
# 8     19366     南部町  ...        NaN         NaN        NaN        NaN
# 9     19208  南アルプス市  ...        NaN         NaN        NaN        NaN
# 10    19212    上野原市  ...        NaN         NaN        NaN        NaN
#
#     月間集計項目9_10月  月間集計項目9_11月  月間集計項目9_12月 月間集計項目9_１月  月間集計項目9_２月  月間集計項目9_３月
# 0           NaN          NaN          NaN        NaN         NaN         NaN
# 1           NaN          NaN          NaN        NaN         NaN         NaN
# 2           NaN          NaN          NaN        NaN         NaN         NaN
# 3           NaN          NaN          NaN        NaN         NaN         NaN
# 4           NaN          NaN          NaN        NaN         NaN         NaN
# 5           NaN          NaN          NaN        NaN         NaN         NaN
# 6           NaN          NaN          NaN        NaN         NaN         NaN
# 7           NaN          NaN          NaN        NaN         NaN         NaN
# 8           NaN          NaN          NaN        NaN         NaN         NaN
# 9           NaN          NaN          NaN        NaN         NaN         NaN
# 10          NaN          NaN          NaN        NaN         NaN         NaN
#
# [11 rows x 143 columns]
# [0.007, 0.014, 0.03]
# [0.007, 0.013, 0.019]
# [0.008, 0.018, 0.02]
# [0.007, 0.013, 0.019]
# [0.008, 0.014, 0.017]
# [0.007, 0.013, 0.021]
# [0.01, 0.017, 0.031]
# [0.014, 0.021, 0.047]
# [0.016, 0.022, 0.055]
# [0.015, 0.019, 0.046]
# [0.016, 0.021, 0.04]
# [0.013, 0.022, 0.035]
# 143
# 2012    測定年度  項目種類コード  項目コード_数字 項目コード_英数字  測定方法コード  都道府県コード 都道府県名     都道府県名_ローマ字  \
# 0  2012        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 1  2012        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 2  2012        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 3  2012        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 4  2012        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 5  2012        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 6  2012        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 7  2012        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 8  2012        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 9  2012        1         4       NOX        2       19   山梨県  Yamanashi-ken
#
#    市区町村コード   市区町村名  ... 月間集計項目9_６月  月間集計項目9_７月 月間集計項目9_８月 月間集計項目9_９月  \
# 0    19201     甲府市  ...        NaN         NaN        NaN        NaN
# 1    19202   富士吉田市  ...        NaN         NaN        NaN        NaN
# 2    19204     都留市  ...        NaN         NaN        NaN        NaN
# 3    19206     大月市  ...        NaN         NaN        NaN        NaN
# 4    19207     韮崎市  ...        NaN         NaN        NaN        NaN
# 5    19208  南アルプス市  ...        NaN         NaN        NaN        NaN
# 6    19211     笛吹市  ...        NaN         NaN        NaN        NaN
# 7    19212    上野原市  ...        NaN         NaN        NaN        NaN
# 8    19213     甲州市  ...        NaN         NaN        NaN        NaN
# 9    19366     南部町  ...        NaN         NaN        NaN        NaN
#
#    月間集計項目9_10月  月間集計項目9_11月  月間集計項目9_12月 月間集計項目9_１月  月間集計項目9_２月  月間集計項目9_３月
# 0          NaN          NaN          NaN        NaN         NaN         NaN
# 1          NaN          NaN          NaN        NaN         NaN         NaN
# 2          NaN          NaN          NaN        NaN         NaN         NaN
# 3          NaN          NaN          NaN        NaN         NaN         NaN
# 4          NaN          NaN          NaN        NaN         NaN         NaN
# 5          NaN          NaN          NaN        NaN         NaN         NaN
# 6          NaN          NaN          NaN        NaN         NaN         NaN
# 7          NaN          NaN          NaN        NaN         NaN         NaN
# 8          NaN          NaN          NaN        NaN         NaN         NaN
# 9          NaN          NaN          NaN        NaN         NaN         NaN
#
# [10 rows x 143 columns]
# [0.009, 0.014, 0.02]
# [0.008, 0.01, 0.02]
# [0.01, 0.017, 0.019]
# [0.009, 0.013, 0.018]
# [0.007, 0.009, 0.019]
# [0.008, 0.012, 0.018]
# [0.007, 0.015, 0.027]
# [0.014, 0.021, 0.039]
# [0.018, 0.025, 0.049]
# [0.022, 0.019, 0.059]
# [0.019, 0.022, 0.039]
# [0.012, 0.02, 0.029]
# 143
# 2013     測定年度  項目種類コード  項目コード_数字 項目コード_英数字  測定方法コード  都道府県コード 都道府県名     都道府県名_ローマ字  \
# 0   2013        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 1   2013        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 2   2013        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 3   2013        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 4   2013        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 5   2013        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 6   2013        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 7   2013        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 8   2013        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 9   2013        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 10  2013        1         4       NOX        2       19   山梨県  Yamanashi-ken
#
#     市区町村コード   市区町村名  ... 月間集計項目9_６月  月間集計項目9_７月 月間集計項目9_８月 月間集計項目9_９月  \
# 0     19201     甲府市  ...        NaN         NaN        NaN        NaN
# 1     19201     甲府市  ...        NaN         NaN        NaN        NaN
# 2     19202   富士吉田市  ...        NaN         NaN        NaN        NaN
# 3     19204     都留市  ...        NaN         NaN        NaN        NaN
# 4     19206     大月市  ...        NaN         NaN        NaN        NaN
# 5     19207     韮崎市  ...        NaN         NaN        NaN        NaN
# 6     19208  南アルプス市  ...        NaN         NaN        NaN        NaN
# 7     19211     笛吹市  ...        NaN         NaN        NaN        NaN
# 8     19212    上野原市  ...        NaN         NaN        NaN        NaN
# 9     19213     甲州市  ...        NaN         NaN        NaN        NaN
# 10    19366     南部町  ...        NaN         NaN        NaN        NaN
#
#     月間集計項目9_10月  月間集計項目9_11月  月間集計項目9_12月 月間集計項目9_１月  月間集計項目9_２月  月間集計項目9_３月
# 0           NaN          NaN          NaN        NaN         NaN         NaN
# 1           NaN          NaN          NaN        NaN         NaN         NaN
# 2           NaN          NaN          NaN        NaN         NaN         NaN
# 3           NaN          NaN          NaN        NaN         NaN         NaN
# 4           NaN          NaN          NaN        NaN         NaN         NaN
# 5           NaN          NaN          NaN        NaN         NaN         NaN
# 6           NaN          NaN          NaN        NaN         NaN         NaN
# 7           NaN          NaN          NaN        NaN         NaN         NaN
# 8           NaN          NaN          NaN        NaN         NaN         NaN
# 9           NaN          NaN          NaN        NaN         NaN         NaN
# 10          NaN          NaN          NaN        NaN         NaN         NaN
#
# [11 rows x 143 columns]
# [0.007, 0.015, 0.024]
# [0.007, 0.013, 0.019]
# [0.008, 0.014, 0.017]
# [0.007, 0.007, 0.017]
# [0.007, 0.01, 0.016]
# [0.007, 0.012, 0.017]
# [0.006, 0.017, 0.021]
# [0.011, 0.018, 0.039]
# [0.013, 0.019, 0.051]
# [0.013, 0.018, 0.05]
# [0.017, 0.024, 0.048]
# [0.011, 0.018, 0.03]
# 143
# 2014     測定年度  項目種類コード  項目コード_数字 項目コード_英数字  測定方法コード  都道府県コード 都道府県名     都道府県名_ローマ字  \
# 0   2014        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 1   2014        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 2   2014        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 3   2014        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 4   2014        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 5   2014        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 6   2014        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 7   2014        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 8   2014        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 9   2014        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 10  2014        1         4       NOX        2       19   山梨県  Yamanashi-ken
#
#     市区町村コード   市区町村名  ... 月間集計項目9_６月  月間集計項目9_７月 月間集計項目9_８月 月間集計項目9_９月  \
# 0     19201     甲府市  ...        NaN         NaN        NaN        NaN
# 1     19201     甲府市  ...        NaN         NaN        NaN        NaN
# 2     19202   富士吉田市  ...        NaN         NaN        NaN        NaN
# 3     19204     都留市  ...        NaN         NaN        NaN        NaN
# 4     19206     大月市  ...        NaN         NaN        NaN        NaN
# 5     19207     韮崎市  ...        NaN         NaN        NaN        NaN
# 6     19208  南アルプス市  ...        NaN         NaN        NaN        NaN
# 7     19211     笛吹市  ...        NaN         NaN        NaN        NaN
# 8     19212    上野原市  ...        NaN         NaN        NaN        NaN
# 9     19213     甲州市  ...        NaN         NaN        NaN        NaN
# 10    19366     南部町  ...        NaN         NaN        NaN        NaN
#
#     月間集計項目9_10月  月間集計項目9_11月  月間集計項目9_12月 月間集計項目9_１月  月間集計項目9_２月  月間集計項目9_３月
# 0           NaN          NaN          NaN        NaN         NaN         NaN
# 1           NaN          NaN          NaN        NaN         NaN         NaN
# 2           NaN          NaN          NaN        NaN         NaN         NaN
# 3           NaN          NaN          NaN        NaN         NaN         NaN
# 4           NaN          NaN          NaN        NaN         NaN         NaN
# 5           NaN          NaN          NaN        NaN         NaN         NaN
# 6           NaN          NaN          NaN        NaN         NaN         NaN
# 7           NaN          NaN          NaN        NaN         NaN         NaN
# 8           NaN          NaN          NaN        NaN         NaN         NaN
# 9           NaN          NaN          NaN        NaN         NaN         NaN
# 10          NaN          NaN          NaN        NaN         NaN         NaN
#
# [11 rows x 143 columns]
# [0.008, 0.016, 0.025]
# [0.006, 0.011, 0.02]
# [0.006, 0.014, 0.017]
# [0.006, 0.013, 0.015]
# [0.005, 0.011, 0.012]
# [0.007, 0.014, 0.017]
# [0.007, 0.015, 0.025]
# [0.01, 0.019, 0.032]
# [0.011, 0.02, 0.041]
# [0.011, 0.02, 0.037]
# [0.012, 0.019, 0.032]
# [0.009, 0.015, 0.023]
# 143
# 2015     測定年度  項目種類コード  項目コード_数字 項目コード_英数字  測定方法コード  都道府県コード 都道府県名     都道府県名_ローマ字  \
# 0   2015        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 1   2015        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 2   2015        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 3   2015        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 4   2015        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 5   2015        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 6   2015        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 7   2015        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 8   2015        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 9   2015        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 10  2015        1         4       NOX        2       19   山梨県  Yamanashi-ken
#
#     市区町村コード   市区町村名  ... 月間集計項目9_６月  月間集計項目9_７月 月間集計項目9_８月 月間集計項目9_９月  \
# 0     19201     甲府市  ...        NaN         NaN        NaN        NaN
# 1     19201     甲府市  ...        NaN         NaN        NaN        NaN
# 2     19202   富士吉田市  ...        NaN         NaN        NaN        NaN
# 3     19204     都留市  ...        NaN         NaN        NaN        NaN
# 4     19206     大月市  ...        NaN         NaN        NaN        NaN
# 5     19207     韮崎市  ...        NaN         NaN        NaN        NaN
# 6     19208  南アルプス市  ...        NaN         NaN        NaN        NaN
# 7     19211     笛吹市  ...        NaN         NaN        NaN        NaN
# 8     19212    上野原市  ...        NaN         NaN        NaN        NaN
# 9     19213     甲州市  ...        NaN         NaN        NaN        NaN
# 10    19366     南部町  ...        NaN         NaN        NaN        NaN
#
#     月間集計項目9_10月  月間集計項目9_11月  月間集計項目9_12月 月間集計項目9_１月  月間集計項目9_２月  月間集計項目9_３月
# 0           NaN          NaN          NaN        NaN         NaN         NaN
# 1           NaN          NaN          NaN        NaN         NaN         NaN
# 2           NaN          NaN          NaN        NaN         NaN         NaN
# 3           NaN          NaN          NaN        NaN         NaN         NaN
# 4           NaN          NaN          NaN        NaN         NaN         NaN
# 5           NaN          NaN          NaN        NaN         NaN         NaN
# 6           NaN          NaN          NaN        NaN         NaN         NaN
# 7           NaN          NaN          NaN        NaN         NaN         NaN
# 8           NaN          NaN          NaN        NaN         NaN         NaN
# 9           NaN          NaN          NaN        NaN         NaN         NaN
# 10          NaN          NaN          NaN        NaN         NaN         NaN
#
# ...
# [0.006, 0.011, 0.015]
# [0.007, 0.012, 0.021]
# [0.01, 0.017, 0.025]
# [0.012, 0.017, 0.036]
# [0.014, 0.016, 0.039]
# [0.011, 0.016, 0.035]
# [0.009, 0.016, 0.022]
# 143
# 2016     測定年度  項目種類コード  項目コード_数字 項目コード_英数字  測定方法コード  都道府県コード 都道府県名     都道府県名_ローマ字  \
# 0   2016        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 1   2016        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 2   2016        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 3   2016        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 4   2016        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 5   2016        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 6   2016        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 7   2016        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 8   2016        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 9   2016        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 10  2016        1         4       NOX        2       19   山梨県  Yamanashi-ken
#
#     市区町村コード   市区町村名  ... 月間集計項目9_６月  月間集計項目9_７月 月間集計項目9_８月 月間集計項目9_９月  \
# 0     19201     甲府市  ...        NaN         NaN        NaN        NaN
# 1     19201     甲府市  ...        NaN         NaN        NaN        NaN
# 2     19202   富士吉田市  ...        NaN         NaN        NaN        NaN
# 3     19204     都留市  ...        NaN         NaN        NaN        NaN
# 4     19206     大月市  ...        NaN         NaN        NaN        NaN
# 5     19207     韮崎市  ...        NaN         NaN        NaN        NaN
# 6     19208  南アルプス市  ...        NaN         NaN        NaN        NaN
# 7     19211     笛吹市  ...        NaN         NaN        NaN        NaN
# 8     19212    上野原市  ...        NaN         NaN        NaN        NaN
# 9     19213     甲州市  ...        NaN         NaN        NaN        NaN
# 10    19366     南部町  ...        NaN         NaN        NaN        NaN
#
#     月間集計項目9_10月  月間集計項目9_11月  月間集計項目9_12月 月間集計項目9_１月  月間集計項目9_２月  月間集計項目9_３月
# 0           NaN          NaN          NaN        NaN         NaN         NaN
# 1           NaN          NaN          NaN        NaN         NaN         NaN
# 2           NaN          NaN          NaN        NaN         NaN         NaN
# 3           NaN          NaN          NaN        NaN         NaN         NaN
# 4           NaN          NaN          NaN        NaN         NaN         NaN
# 5           NaN          NaN          NaN        NaN         NaN         NaN
# 6           NaN          NaN          NaN        NaN         NaN         NaN
# 7           NaN          NaN          NaN        NaN         NaN         NaN
# 8           NaN          NaN          NaN        NaN         NaN         NaN
# 9           NaN          NaN          NaN        NaN         NaN         NaN
# 10          NaN          NaN          NaN        NaN         NaN         NaN
#
# [11 rows x 143 columns]
# [0.007, 0.012, 0.018]
# [0.005, 0.009, 0.016]
# [0.005, 0.01, 0.012]
# [0.006, 0.01, 0.012]
# [0.005, 0.009, 0.011]
# [0.006, 0.012, 0.014]
# [0.007, 0.013, 0.02]
# [0.01, 0.014, 0.026]
# [0.01, 0.015, 0.035]
# [0.011, 0.013, 0.033]
# [0.008, 0.012, 0.023]
# [0.01, 0.014, 0.024]
# 143
# 2017     測定年度  項目種類コード  項目コード_数字 項目コード_英数字  測定方法コード  都道府県コード 都道府県名     都道府県名_ローマ字  \
# 0   2017        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 1   2017        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 2   2017        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 3   2017        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 4   2017        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 5   2017        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 6   2017        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 7   2017        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 8   2017        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 9   2017        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 10  2017        1         4       NOX        2       19   山梨県  Yamanashi-ken
#
#     市区町村コード   市区町村名  ... 月間集計項目9_６月  月間集計項目9_７月 月間集計項目9_８月 月間集計項目9_９月  \
# 0     19201     甲府市  ...        NaN         NaN        NaN        NaN
# 1     19201     甲府市  ...        NaN         NaN        NaN        NaN
# 2     19202   富士吉田市  ...        NaN         NaN        NaN        NaN
# 3     19204     都留市  ...        NaN         NaN        NaN        NaN
# 4     19206     大月市  ...        NaN         NaN        NaN        NaN
# 5     19207     韮崎市  ...        NaN         NaN        NaN        NaN
# 6     19208  南アルプス市  ...        NaN         NaN        NaN        NaN
# 7     19211     笛吹市  ...        NaN         NaN        NaN        NaN
# 8     19212    上野原市  ...        NaN         NaN        NaN        NaN
# 9     19213     甲州市  ...        NaN         NaN        NaN        NaN
# 10    19366     南部町  ...        NaN         NaN        NaN        NaN
#
#     月間集計項目9_10月  月間集計項目9_11月  月間集計項目9_12月 月間集計項目9_１月  月間集計項目9_２月  月間集計項目9_３月
# 0           NaN          NaN          NaN        NaN         NaN         NaN
# 1           NaN          NaN          NaN        NaN         NaN         NaN
# 2           NaN          NaN          NaN        NaN         NaN         NaN
# 3           NaN          NaN          NaN        NaN         NaN         NaN
# 4           NaN          NaN          NaN        NaN         NaN         NaN
# 5           NaN          NaN          NaN        NaN         NaN         NaN
# 6           NaN          NaN          NaN        NaN         NaN         NaN
# 7           NaN          NaN          NaN        NaN         NaN         NaN
# 8           NaN          NaN          NaN        NaN         NaN         NaN
# 9           NaN          NaN          NaN        NaN         NaN         NaN
# 10          NaN          NaN          NaN        NaN         NaN         NaN
#
# [11 rows x 143 columns]
# [0.007, 0.011, 0.017]
# [0.007, 0.009, 0.015]
# [0.007, 0.008, 0.013]
# [0.006, 0.005, 0.012]
# [0.007, 0.005, 0.011]
# [0.006, 0.006, 0.013]
# [0.007, 0.009, 0.015]
# [0.009, 0.009, 0.032]
# [0.012, 0.01, 0.035]
# [0.011, 0.011, 0.031]
# [0.012, 0.013, 0.027]
# [0.009, 0.013, 0.021]
# 143
# 2018     測定年度  項目種類コード  項目コード_数字 項目コード_英数字  測定方法コード  都道府県コード 都道府県名     都道府県名_ローマ字  \
# 0   2018        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 1   2018        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 2   2018        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 3   2018        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 4   2018        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 5   2018        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 6   2018        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 7   2018        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 8   2018        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 9   2018        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 10  2018        1         4       NOX        2       19   山梨県  Yamanashi-ken
#
#     市区町村コード   市区町村名  ... 月間集計項目9_６月  月間集計項目9_７月 月間集計項目9_８月 月間集計項目9_９月  \
# 0     19201     甲府市  ...        NaN         NaN        NaN        NaN
# 1     19201     甲府市  ...        NaN         NaN        NaN        NaN
# 2     19202   富士吉田市  ...        NaN         NaN        NaN        NaN
# 3     19204     都留市  ...        NaN         NaN        NaN        NaN
# 4     19206     大月市  ...        NaN         NaN        NaN        NaN
# 5     19207     韮崎市  ...        NaN         NaN        NaN        NaN
# 6     19208  南アルプス市  ...        NaN         NaN        NaN        NaN
# 7     19211     笛吹市  ...        NaN         NaN        NaN        NaN
# 8     19212    上野原市  ...        NaN         NaN        NaN        NaN
# 9     19213     甲州市  ...        NaN         NaN        NaN        NaN
# 10    19366     南部町  ...        NaN         NaN        NaN        NaN
#
#     月間集計項目9_10月  月間集計項目9_11月  月間集計項目9_12月 月間集計項目9_１月  月間集計項目9_２月  月間集計項目9_３月
# 0           NaN          NaN          NaN        NaN         NaN         NaN
# 1           NaN          NaN          NaN        NaN         NaN         NaN
# 2           NaN          NaN          NaN        NaN         NaN         NaN
# 3           NaN          NaN          NaN        NaN         NaN         NaN
# 4           NaN          NaN          NaN        NaN         NaN         NaN
# 5           NaN          NaN          NaN        NaN         NaN         NaN
# 6           NaN          NaN          NaN        NaN         NaN         NaN
# 7           NaN          NaN          NaN        NaN         NaN         NaN
# 8           NaN          NaN          NaN        NaN         NaN         NaN
# 9           NaN          NaN          NaN        NaN         NaN         NaN
# 10          NaN          NaN          NaN        NaN         NaN         NaN
#
# [11 rows x 143 columns]
# [0.005, 0.009, 0.014]
# [0.005, 0.008, 0.013]
# [0.005, 0.008, 0.011]
# [0.005, 0.007, 0.011]
# [0.004, 0.007, 0.011]
# [0.005, 0.009, 0.01]
# [0.006, 0.011, 0.015]
# [0.009, 0.014, 0.022]
# [0.011, 0.015, 0.029]
# [0.01, 0.014, 0.029]
# [0.011, 0.017, 0.028]
# [0.008, 0.012, 0.017]
# 143
# 2019     測定年度  項目種類コード  項目コード_数字 項目コード_英数字  測定方法コード  都道府県コード 都道府県名     都道府県名_ローマ字  \
# 0   2019        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 1   2019        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 2   2019        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 3   2019        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 4   2019        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 5   2019        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 6   2019        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 7   2019        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 8   2019        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 9   2019        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 10  2019        1         4       NOX        2       19   山梨県  Yamanashi-ken
#
#     市区町村コード   市区町村名  ... 月間集計項目9_６月  月間集計項目9_７月 月間集計項目9_８月 月間集計項目9_９月  \
# 0     19201     甲府市  ...        NaN         NaN        NaN        NaN
# 1     19201     甲府市  ...        NaN         NaN        NaN        NaN
# 2     19202   富士吉田市  ...        NaN         NaN        NaN        NaN
# 3     19204     都留市  ...        NaN         NaN        NaN        NaN
# 4     19206     大月市  ...        NaN         NaN        NaN        NaN
# 5     19207     韮崎市  ...        NaN         NaN        NaN        NaN
# 6     19208  南アルプス市  ...        NaN         NaN        NaN        NaN
# 7     19211     笛吹市  ...        NaN         NaN        NaN        NaN
# 8     19212    上野原市  ...        NaN         NaN        NaN        NaN
# 9     19213     甲州市  ...        NaN         NaN        NaN        NaN
# 10    19366     南部町  ...        NaN         NaN        NaN        NaN
#
#     月間集計項目9_10月  月間集計項目9_11月  月間集計項目9_12月 月間集計項目9_１月  月間集計項目9_２月  月間集計項目9_３月
# 0           NaN          NaN          NaN        NaN         NaN         NaN
# 1           NaN          NaN          NaN        NaN         NaN         NaN
# 2           NaN          NaN          NaN        NaN         NaN         NaN
# 3           NaN          NaN          NaN        NaN         NaN         NaN
# 4           NaN          NaN          NaN        NaN         NaN         NaN
# 5           NaN          NaN          NaN        NaN         NaN         NaN
# 6           NaN          NaN          NaN        NaN         NaN         NaN
# 7           NaN          NaN          NaN        NaN         NaN         NaN
# 8           NaN          NaN          NaN        NaN         NaN         NaN
# 9           NaN          NaN          NaN        NaN         NaN         NaN
# 10          NaN          NaN          NaN        NaN         NaN         NaN
#
# [11 rows x 143 columns]
# [0.007, 0.01, 0.014]
# [0.005, 0.008, 0.013]
# [0.005, 0.009, 0.01]
# [0.006, 0.01, 0.009]
# [0.004, 0.007, 0.01]
# [0.005, 0.007, 0.01]
# [0.006, 0.021, 0.01]
# [0.008, 0.025, 0.018]
# [0.01, 0.013, 0.024]
# [0.01, 0.012, 0.022]
# [0.008, 0.011, 0.02]
# [0.006, 0.008, 0.014]
# 143
# 2020     測定年度  項目種類コード  項目コード_数字 項目コード_英数字  測定方法コード  都道府県コード 都道府県名     都道府県名_ローマ字  \
# 0   2020        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 1   2020        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 2   2020        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 3   2020        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 4   2020        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 5   2020        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 6   2020        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 7   2020        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 8   2020        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 9   2020        1         4       NOX        2       19   山梨県  Yamanashi-ken
# 10  2020        1         4       NOX        2       19   山梨県  Yamanashi-ken
#
#     市区町村コード   市区町村名  ... 月間集計項目9_６月  月間集計項目9_７月 月間集計項目9_８月 月間集計項目9_９月  \
# 0     19201     甲府市  ...        NaN         NaN        NaN        NaN
# 1     19201     甲府市  ...        NaN         NaN        NaN        NaN
# 2     19202   富士吉田市  ...        NaN         NaN        NaN        NaN
# 3     19204     都留市  ...        NaN         NaN        NaN        NaN
# 4     19206     大月市  ...        NaN         NaN        NaN        NaN
# 5     19207     韮崎市  ...        NaN         NaN        NaN        NaN
# 6     19208  南アルプス市  ...        NaN         NaN        NaN        NaN
# 7     19211     笛吹市  ...        NaN         NaN        NaN        NaN
# 8     19212    上野原市  ...        NaN         NaN        NaN        NaN
# 9     19213     甲州市  ...        NaN         NaN        NaN        NaN
# 10    19366     南部町  ...        NaN         NaN        NaN        NaN
#
#     月間集計項目9_10月  月間集計項目9_11月  月間集計項目9_12月 月間集計項目9_１月  月間集計項目9_２月  月間集計項目9_３月
# 0           NaN          NaN          NaN        NaN         NaN         NaN
# 1           NaN          NaN          NaN        NaN         NaN         NaN
# 2           NaN          NaN          NaN        NaN         NaN         NaN
# 3           NaN          NaN          NaN        NaN         NaN         NaN
# 4           NaN          NaN          NaN        NaN         NaN         NaN
# 5           NaN          NaN          NaN        NaN         NaN         NaN
# 6           NaN          NaN          NaN        NaN         NaN         NaN
# 7           NaN          NaN          NaN        NaN         NaN         NaN
# 8           NaN          NaN          NaN        NaN         NaN         NaN
# 9           NaN          NaN          NaN        NaN         NaN         NaN
# 10          NaN          NaN          NaN        NaN         NaN         NaN
#
# [11 rows x 143 columns]
# [0.005, 0.006, 0.011]
# [0.004, 0.004, 0.008]
# [0.004, 0.005, 0.008]
# [0.004, 0.005, 0.008]
# [0.004, 0.005, 0.009]
# [0.004, 0.005, 0.008]
# [0.006, 0.007, 0.011]
# [0.007, 0.009, 0.023]
# [0.009, 0.011, nan]
# [0.01, 0.013, 0.028]
# [0.007, 0.01, 0.02]
# [0.006, 0.007, 0.015]
#      19202030  19204010  19206010
# 0       0.011     0.024     0.030
# 1       0.009     0.027     0.024
# 2       0.011     0.029     0.027
# 3       0.010     0.023     0.023
# 4       0.011     0.023     0.022
# ..        ...       ...       ...
# 247     0.007     0.009     0.023
# 248     0.009     0.011       NaN
# 249     0.010     0.013     0.028
# 250     0.007     0.010     0.020
# 251     0.006     0.007     0.015
#
# [252 rows x 3 columns]

# %%
# Google Colab
! pip install japanize_matplotlib
# Out:
# Requirement already satisfied: japanize_matplotlib in /Users/matto/.local/share/virtualenvs/boo-nVtRHqCN/lib/python3.11/site-packages (1.1.3)
# Requirement already satisfied: matplotlib in /Users/matto/.local/share/virtualenvs/boo-nVtRHqCN/lib/python3.11/site-packages (from japanize_matplotlib) (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/matto/.local/share/virtualenvs/boo-nVtRHqCN/lib/python3.11/site-packages (from matplotlib->japanize_matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/matto/.local/share/virtualenvs/boo-nVtRHqCN/lib/python3.11/site-packages (from matplotlib->japanize_matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/matto/.local/share/virtualenvs/boo-nVtRHqCN/lib/python3.11/site-packages (from matplotlib->japanize_matplotlib) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/matto/.local/share/virtualenvs/boo-nVtRHqCN/lib/python3.11/site-packages (from matplotlib->japanize_matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in /Users/matto/.local/share/virtualenvs/boo-nVtRHqCN/lib/python3.11/site-packages (from matplotlib->japanize_matplotlib) (1.26.2)
# Requirement already satisfied: packaging>=20.0 in /Users/matto/.local/share/virtualenvs/boo-nVtRHqCN/lib/python3.11/site-packages (from matplotlib->japanize_matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in /Users/matto/.local/share/virtualenvs/boo-nVtRHqCN/lib/python3.11/site-packages (from matplotlib->japanize_matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/matto/.local/share/virtualenvs/boo-nVtRHqCN/lib/python3.11/site-packages (from matplotlib->japanize_matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/matto/.local/share/virtualenvs/boo-nVtRHqCN/lib/python3.11/site-packages (from matplotlib->japanize_matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/matto/.local/share/virtualenvs/boo-nVtRHqCN/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->japanize_matplotlib) (1.16.0)
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# 3変数線形回帰により、背景と大気質依存成分を分離する。
#
# 大気以外に由来する窒素が経年減少しないとした、もとの回帰式はこちら。
# $$c_r=c(B/F_r+C)+D/F_r+E$$
#
# これに対し、後半の大気以外由来部分が直線的に減少するような仕掛けを追加する。
# $$c_r=c(B/F_r+C)+D/F_r+E + Gt$$

# %%
import numpy as np
import scipy
import japanize_matplotlib
import plotly.graph_objects as go
import plotly.io as pio
import matplotlib.pyplot as plt


def trend(cFt, B, C, D, E, G):
    c, F, t = cFt
    return c * (B / F + C) + D / F + E + G * t


bridges = [
    ("昭和橋", 19202030),
    ("富士見橋", 19202030),
    ("大月橋", 19204010),
    ("桂川橋", 19206010),
    ("鶴川橋", 19206010),
    ("西方寺橋", 19206010),
    ("落合橋", 19206010),
    ("流川", 19206010),
    ("道志川", 19206010),
    ("秋山川", 19206010),
    ("桂川橋", 19204010),
    ("鶴川橋", 19204010),
    ("西方寺橋", 19204010),
    ("落合橋", 19204010),
    ("流川", 19204010),
    ("道志川", 19204010),
    ("秋山川", 19204010),
]


for bridge, station in bridges:
    flowcol = f"('{bridge}', '流量')"  # 単位はm3/s
    noxcol = f"('{bridge}', '全窒素')"  # 単位はppm ~ g/m3

    # NOX in the air
    c = nox[station].ffill()

    # River flow
    F = flows[flowcol]

    # N load
    N = flows[flowcol] * flows[noxcol]

    # t time
    t = np.arange(len(N))

    popt, pcov = scipy.optimize.curve_fit(trend, (c, F, t), N / F)
    B, C, D, E, G = popt

    X = t
    Y = N / F
    plt.plot(X, Y, "-", markersize=2, label="実測")
    plt.stackplot(
        X,
        trend((c, F, t), B, C, 0, 0, 0),
        trend((c, F, t), 0, 0, D, E, G),
        baseline="zero",
        labels=["大気由来(乾性沈着)", "大気由来(湿性沈着)", "その他"],
    )
    # plt.yscale("log")
    plt.title(bridge)
    plt.xlabel("時間 (月)")
    plt.ylabel("窒素濃度 (mg N/L)")
    # plt.ylim(0,100)
    plt.legend()
    plt.show()

    plt.scatter(N / F, trend((c, F, t), B, C, D, E, G))
    X = np.linspace(0, np.max(trend((c, F, t), B, C, D, E, G)), 10)
    plt.plot(X, X, "-")
    plt.title(bridge)
    plt.xlabel("窒素濃度 (mg N/L) 実測")
    plt.ylabel("窒素濃度 (mg N/L) 回帰")
    plt.xlim(0, None)
    plt.ylim(0, None)
    # plt.legend()
    plt.show()

print("bridge\tstation\tB\tC\tD\tE\tG\trmse\tcorr\tair")
for bridge, station in bridges:
    flowcol = f"('{bridge}', '流量')"  # 単位はm3/s
    noxcol = f"('{bridge}', '全窒素')"  # 単位はppm ~ g/m3

    # NOX in the air
    c = nox[station].ffill()

    # River flow
    F = flows[flowcol]

    # N load
    N = flows[flowcol] * flows[noxcol]

    # t time
    t = np.arange(len(N))

    popt, pcov = scipy.optimize.curve_fit(trend, (c, F, t), N / F, p0=popt)
    B, C, D, E, G = popt

    print(
        f"{bridge}\t{station}\t{B:.3f}\t{C:.3f}\t{D:.3f}\t{E:.3f}\t{G:.3f}\t",
        end="",
    )
    rmse = np.mean((N - trend((c, F, t), B, C, D, E, G)) ** 2) ** 0.5
    coeff = np.corrcoef(N, trend((c, F, t), B, C, D, E, G))[0, 1]
    air = (
        np.mean(trend((c, F, t), B, C, 0, 0, 0) / trend((c, F, t), B, C, D, E, G)) * 100
    )
    print(f"{rmse:.3f}\t{coeff:.3f}\t{air:.3f}")
# Out:
# bridge	station	B	C	D	E	G	rmse	corr	air
# 昭和橋	19202030	24.467	11.164	0.317	0.583	-0.001	1.717	-0.320	28.298
# 富士見橋	19202030	7.662	3.808	-0.489	1.231	-0.001	5.393	0.286	5.692
# 大月橋	19204010	-1.927	3.931	0.445	1.318	-0.002	9.456	-0.138	4.554
# 桂川橋	19206010	-109.489	5.727	7.638	1.127	-0.001	48.292	0.074	5.373
# 鶴川橋	19206010	2.779	-0.655	0.066	1.435	-0.003	2.293	-0.079	3.855
# 西方寺橋	19206010	1.571	-0.735	-0.019	1.215	-0.002	1.752	0.163	0.940
# 落合橋	19206010	0.048	1.706	0.010	1.082	-0.001	0.784	-0.160	5.493
# 流川	19206010	-0.688	1.654	0.171	1.658	-0.002	2.549	0.222	2.561
# 道志川	19206010	-2.973	0.591	0.122	0.685	-0.001	2.655	0.213	-1.103
# 秋山川	19206010	-1.143	1.245	0.038	1.134	-0.002	0.911	0.317	0.094
# 桂川橋	19204010	-189.682	9.392	7.763	1.123	-0.001	48.293	0.060	5.047
# 鶴川橋	19204010	6.324	1.634	0.036	1.338	-0.002	2.292	-0.073	9.548
# 西方寺橋	19204010	4.759	-3.631	-0.055	1.268	-0.002	1.753	0.155	-0.874
# 落合橋	19204010	0.154	1.774	0.009	1.102	-0.001	0.784	-0.166	4.212
# 流川	19204010	0.513	3.214	0.147	1.630	-0.002	2.549	0.220	4.078
# 道志川	19204010	-8.511	1.836	0.185	0.670	-0.001	2.655	0.216	-1.203
# 秋山川	19204010	-4.106	1.669	0.078	1.166	-0.002	0.909	0.326	-5.010

# %% [markdown]
# うまくフィットできていない場合もあるが、予測通り、大気以外の寄与も減少傾向にあるという仮定を置くと、大気寄与はさらに小さく見積もられる。つまり、大気由来の窒素を減らしても、水質は改善しない。
